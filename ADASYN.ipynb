# %% [markdown]
# This notebook includes ADASYN applied to the training set and visualisations of the oversampling technique (distribution of the resampled data and t-SNE).

# %% [markdown]
# # **Import libraries and data**

# %%
# !pip install git+https://github.com/paobranco/ImbalancedLearningRegression.git

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import ImbalancedLearningRegression as iblr
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# %%
#Train data set consists of X_train_ig (with 500 features selected by Information Gain in Feature Selection notebook) and y_train
data_train_ig.head()
# Out:
#    seq_TEMP         A         C         E         I         K         L  \
# 0        26  0.128743  0.023952  0.059880  0.041916  0.017964  0.083832
# 1        30  0.076923  0.008547  0.094017  0.065527  0.068376  0.096866
# 2        74  0.043937  0.001757  0.072056  0.108963  0.077329  0.075571
# 3        90  0.066055  0.009174  0.102752  0.047706  0.051376  0.095413
# 4        29  0.067146  0.007194  0.086331  0.074341  0.050360  0.076739
#
#           N         Q         R  ...  Normalized van der Waals Volume-T2332  \
# 0  0.020958  0.020958  0.083832  ...                               0.156156
# 1  0.051282  0.025641  0.031339  ...                               0.180000
# 2  0.047452  0.015817  0.038664  ...                               0.209507
# 3  0.011009  0.020183  0.106422  ...                               0.200368
# 4  0.047962  0.069544  0.045564  ...                               0.197115
#
#    Polarity-T1331  Polarizability-T2332  Charge-T1221  Charge-T1331  \
# ...

# %%
#The training set consists of 2,041 observations
data_train_ig.shape
# Out:
# (2041, 501)

# %% [markdown]
# # **Generate synthetic values**

# %% [markdown]
# Adaptive Synthetic Sampling and the Stacking Algorithm (ADASYN): similar to SMOTE it generates synthetic data based on 5-nearest neighbors but based on data density. It considers deviations of synthesized samples from original samples and adds more data in the areas with low density of rare values. The code is borrowed from https://github.com/paobranco/ImbalancedLearningRegression.git

# %%
## conduct ADASYN
data_train_adasyn = iblr.adasyn(
    
    data = data_train_ig,  ## pandas dataframe
    y = 'seq_TEMP'  ## string ('header name'),
)
# Out:
# ...
# ori_index: 100%|##########| 476/476 [00:00<00:00, 1863.11it/s]

# %%
#The training set increased from 2,041 to 2,581 observations
X_train_adasyn.shape
# Out:
# (2581, 500)

# %% [markdown]
# # **Distribution of ADASYN vs Original**

# %% [markdown]
# To compare the distribution of Topt in the original and oversampled sets.

# %%
#Define X and y for the resampled training set
X_train_adasyn = data_train_adasyn.drop(['seq_TEMP'], axis = 1)
y_train_adasyn = data_train_adasyn['seq_TEMP']

# %%
## plot y distribution 
sns.set_style("white")
sns.kdeplot(data_train_ig['seq_TEMP'], label = "Original", color="grey")
sns.kdeplot(data_train_adasyn['seq_TEMP'], label = "ADASYN")
plt.legend(labels=["Original","ADASYN"])
plt.xlabel("Topt (°C)")
plt.ylabel("Density")
#plt.title("Distribution of ADASYN vs Original")
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# # **t-SNE for selected features**

# %% [markdown]
# T-SNE is applied to visualize the distribution of the resampled testing data into two-dimensional scale.

# %%
data_train_adasyn_sc = scaler.fit_transform(data_train_adasyn.drop(['seq_TEMP'], axis=1))

embedding_adasyn = TSNE(n_components=2)

# transform on features
new_tsne_adasyn = embedding.fit_transform(data_train_adasyn_sc)

# reconstruct dataframe
new_tsne_adasyn = pd.DataFrame(new_tsne_adasyn, columns=[f"TSNE{i+1}" for i in range(new_tsne_adasyn.shape[1])])
new_tsne_adasyn["seq_TEMP"] = data_train_adasyn["seq_TEMP"]

# %%
#Code for displaying principal components
#Code for displaying principal components
sns.set_style("white")
plt.scatter(new_tsne_adasyn.TSNE1, new_tsne_adasyn.TSNE2, s=5)
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.title("ADASYN")
plt.show()
