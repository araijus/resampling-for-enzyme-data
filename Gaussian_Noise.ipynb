# %% [markdown]
# This notebook includes Gaussian Noise applied to the training set and visualisations of the oversampling technique (distribution of the resampled data and t-SNE).

# %% [markdown]
# # **Import libraries and data**

# %%
# !pip install git+https://github.com/paobranco/ImbalancedLearningRegression.git

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import ImbalancedLearningRegression as iblr
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# %%
#Train data set consists of X_train_ig (with 500 features selected by Information Gain in Feature Selection notebook) and y_train
data_train_ig.head()
# Out:
#    seq_TEMP         A         C         E         I         K         L  \
# 0        26  0.128743  0.023952  0.059880  0.041916  0.017964  0.083832
# 1        30  0.076923  0.008547  0.094017  0.065527  0.068376  0.096866
# 2        74  0.043937  0.001757  0.072056  0.108963  0.077329  0.075571
# 3        90  0.066055  0.009174  0.102752  0.047706  0.051376  0.095413
# 4        29  0.067146  0.007194  0.086331  0.074341  0.050360  0.076739
#
#           N         Q         R  ...  Normalized van der Waals Volume-T2332  \
# 0  0.020958  0.020958  0.083832  ...                               0.156156
# 1  0.051282  0.025641  0.031339  ...                               0.180000
# 2  0.047452  0.015817  0.038664  ...                               0.209507
# 3  0.011009  0.020183  0.106422  ...                               0.200368
# 4  0.047962  0.069544  0.045564  ...                               0.197115
#
#    Polarity-T1331  Polarizability-T2332  Charge-T1221  Charge-T1331  \
# ...

# %%
#The training set consists of 2,041 observations
data_train_ig.shape
# Out:
# (2041, 501)

# %% [markdown]
# # **Generate synthetic values**

# %% [markdown]
# Gaussian Noise (GN): this algorithm adds Gaussian noise to the interpolation and undersamples abundant values. It ensures that the distribution of the synthetic data does not differ extremely from the original minority sample. The code is borrowed from https://github.com/paobranco/ImbalancedLearningRegression.git

# %%
## conduct GN
data_train_gn = iblr.gn(
    
    data = data_train_ig,  ## pandas dataframe
    y = 'seq_TEMP',  ## string ('header name'),
    rel_thres = 0.7, ## relevance threshold considered rare
    under_samp = False
)
# Out:
# ...
# r_index: 100%|##########| 151/151 [00:29<00:00,  5.06it/s]

# %%
#The training set increased from 2,041 to 2,626 observations
X_train_gn.shape
# Out:
# (2626, 500)

# %% [markdown]
# # **Distribution of GN vs Original**

# %% [markdown]
# To compare the distribution of Topt in the original and oversampled sets.

# %%
#Define X and y for the resampled training set
X_train_gn = data_train_gn.drop(['seq_TEMP'], axis = 1)
y_train_gn = data_train_gn['seq_TEMP']

# %%
## plot y distribution 
sns.set_style("white")
sns.kdeplot(data_train_ig['seq_TEMP'], label = "Original", color="grey")
sns.kdeplot(data_train_gn['seq_TEMP'], label = "GN")
plt.legend(labels=["Original","GN"])
plt.xlabel("Topt (°C)")
plt.ylabel("Density")
#plt.title("Distribution of GN vs Original")
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# # **t-SNE for selected features**

# %% [markdown]
# T-SNE is applied to visualize the distribution of the resampled testing data into two-dimensional scale.

# %%
scaler = StandardScaler()

data_train_gn_sc = scaler.fit_transform(data_train_gn.drop(['seq_TEMP'], axis=1))

embedding = TSNE(n_components=2)

# transform on features
new_tsne_gn = embedding.fit_transform(data_train_gn_sc)

# reconstruct dataframe
new_tsne_gn = pd.DataFrame(new_tsne_gn, columns=[f"TSNE{i+1}" for i in range(new_tsne_gn.shape[1])])
new_tsne_gn["seq_TEMP"] = data_train_gn["seq_TEMP"]

# %%
#Code for displaying principal components
#Code for displaying principal components
sns.set_style("white")
plt.scatter(new_tsne_gn.TSNE1, new_tsne_gn.TSNE2, s=5)
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.title("Gaussian Noise")
plt.show()
